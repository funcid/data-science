# %% [markdown]
# # Случайная величина

# %% [markdown]
# <strong>Случайная величина</strong> - переменная, значения которой являются результатом случайного эксперимента.
#
# 1. Дискретные - счетное количество значений
# 2. Непрерывные - принимают <i>все</i> значения из промежутка
#
# 6. Случайная величина одномерная. Борелевская сигма-алгебра.
# Примеры. Распределение случайной величины.
# 7. Случайная величина. Фильтрация сигма-алгебр. Измеримость.
# 8. Виды распределений случайной величины. Функция распределения
# и ее свойства.
# 9. Виды абсолютно непрерывных распределений случайной величины.
# Плотность распределения.
# 10.Независимость случайных величин. Функция от случайной
# величины.
# 15.Последовательность случайных величин. Виды сходимости случайных величин. Примеры.
# 17. Характеристическая функция случайной величины. Ее свойства.
# 18. Моменты случайной величины. Их свойства.
